# %% [markdown]
# Auteur: Nicolas Rousset
# Github: https://github.com/aenori
# Mail: nrousset@gmail.com
# Licence: MIT

# %% [markdown]
# # Python Data Analysis - Python First Practice
#
# Certains des exercices décrits ci-dessous sont très simples et simplement destinés à vérifier la compréhension de base de la langue python.
#
# N'hésitez pas à en ignorer si vous pensez qu'ils ne conviennent pas à vos besoins.

# %% [markdown]
# ## Partie 1: Premier contact avec Python

# %% [markdown]
# ### Autotest Cell
#
# Vous devez exécuter cette cellule pour permettre à tous les tests de cette partie de fonctionner.

# %%
import binascii

test_notebook_td_2_content = b'...'
cours_python_utils_content = b'...'

with open( 'test_notebook_td_2.py', 'wb' ) as f:
    f.write( binascii.unhexlify(test_notebook_td_2_content)  )
with open( 'cours_python_utils.py', 'wb' ) as f:
    f.write( binascii.unhexlify(cours_python_utils_content)  )

# %% [markdown]
# ### Exercice n ° 0: [py] Bonjour le monde!
#
# **Rien à faire ici, cet exercice sert à vérifier que les tests unitaires fonctionnent**
#
# Écrivez une variable <code>i</code> qui contient la chaîne "Hello World!"

# %%
## Exercise 2-0
i = "Hello world !"

try:
    import test_notebook_td_2
    test_notebook_td_2.tester_exo( '0', globals() )
except ImportError:
    print("You didn't execute the cell for autotest" )
    raise

# %% [markdown]
# **Exemple:** À L'exécution de la cellule ci-dessous, elle doit afficher "Hello World!"

# %%
print(i)

# %% [markdown]
# ### Exercice N ° 1: [PY] Création d'une variable

# %% [markdown]
# Créez une variable nommée <code>a1</code>, de valeur 5.

# %%
## Exercise 2-1


## Don't touch the following lines
import test_notebook_td_2
test_notebook_td_2.tester_exo( '2_1', globals() )

# %% [markdown]
# ### Exercice N ° 2: [Py] Création d'une variable de type float

# %% [markdown]
# Créer une variable <code>a2</code>, de valeur 5.0 (donc le type doit être <code>float</code>)

# %%
## Exercise 2-2


## Don't touch the following lines
import test_notebook_td_2
test_notebook_td_2.tester_exo( '2_2', globals() )

# %% [markdown]
# ### Exercice n ° 5: [PY] factoriel

# %% [markdown]
# Calculez 999! (factoriel de 999), dans une variable nommée <code>resultat2_5</code> (ce sera celui qui sera testé)
#
# $ x = 1 * 2 * 3 * ... * 997 * 998 * 999 $
#
# Pour rappel, vous pouvez utiliser la boucle FOR et la méthode de plage pour boucler sur tout le nombre jusqu'à 1000 (exclu)
#
# ~~~
# for it in range(1000):
# ~~~

# %%
## Exercise 2-5


## Don't touch the following lines
import test_notebook_td_2
test_notebook_td_2.tester_exo( '2_5', globals() )

# %% [markdown]
# **Exemple:** Si vous essayez le produit du numéro de 1 à 9, la réponse doit être: **362880**

# %% [markdown]
# ### Exercice N ° 6: [Py] Somme de nombres carrés

# %% [markdown]
# Calculez la somme du nombre carré de 0 à 1487, dans une variable **resultat2_6**
#
# <code>resultat2_6</code> = $ 1 ^ 2 + 2 ^ 2 + 3 ^ 2 + ... + 1487 ^ 2 $

# %%
## Exercise 2-6

    
## Don't touch the following lines
import test_notebook_td_2
test_notebook_td_2.tester_exo( '2_6', globals() )

# %% [markdown]
# ### Exercice N ° 7: [PY] Calcul de somme partielle
#
# Calculez la somme de tous les nombres de 1 à 1000 qui peuvent être divisées par 3, c'est-à-dire:
#
# $ 3 + 6 + 9 + ... + 993 + 996 + 999 $
#
# Vous pouvez utiliser l'opérateur modulo pour savoir si un nombre peut être divisé par un autre numéro
#
# ~~~
# if x % 3 == 0:
# ...
# ~~~
#
# Mettez le résultat dans une variable <code>resultat2_7</code> (celle-ci sera vérifiée dans un test)

# %%
## Exercise 2-7


## Don't touch the following lines
import test_notebook_td_2
test_notebook_td_2.tester_exo( '2_7', globals() )

# %% [markdown]
# ### Exercice N ° 9: [PY] Calcul exponentiel
#
# Un peu plus difficile :-)
#
# Calculez, sans utiliser le module mathématique ou numpy, $e ^ {10}$ <code>exp(10)</code> (que vous stockerez dans une variable **resultat2_9**)
#
# Il existe une formule approchée pour exponentiel:
#
# $ e^n = \sum_{k = 0}^{1000}{\frac{n ^ k}{k!}} $
#
# Avec $ 0^0 = 1 $ et $0! = 1$
#
# L'objectif est d'utiliser le code que vous avez écrit dans les exercices précédents.

# %%
## Exercise 2-9


## Don't modify following lines
import test_notebook_td_2
test_notebook_td_2.tester_exo( '2_9', globals() )

# %%
import math
math.exp(10)

# %% [markdown]
# ## Partie 2: Fonctions
#
# ** IMPORTANT !! ** Vous devez exécuter la cellule suivante pour activer les tests automatiques

# %%
import binascii

test_notebook_td_3_content = b'...'
cours_python_utils_content = b'...'

with open( 'test_notebook_td_3.py', 'wb' ) as f:
    f.write( binascii.unhexlify(test_notebook_td_3_content)  )
with open( 'cours_python_utils.py', 'wb' ) as f:
    f.write( binascii.unhexlify(cours_python_utils_content)  )

# %% [markdown]
# ### Exercice n ° 0: fonction Bonjour Monde!
#
# Encore une fois, cet exercice contient déjà sa correction, ce n'est qu'une vérification de l'autotest.

# %%
## Exercise 2-0
def hello_world():
     return "Hello world !"

try:
    import test_notebook_td_3
    test_notebook_td_3.tester_exo( '0', globals() )
except ImportError:
    print("Vous devez exécutez la cellule en début de partie 2 " + 
          "celle mentionnée comme nécessaire aux tests unitaires" )
    raise
except Exception as e:
    print("Une erreur assez étrange est arrivée, essayer de redémarrer le serveur " + 
          "ou demandez au prof")
    raise

# %% [markdown]
# **Exemple:** À l'exécution de la cellule ci-dessous, elle doit afficher "Hello World!"

# %%
print(hello_world())

# %% [markdown]
# ### Exercice n ° 1: fonction un

# %% [markdown]
# Écrivez une fonction <code>un</code> qui ne prend pas l'argument et renvoie la valeur 1.

# %%
## Exercise 2-1


## Don't touch the following lines
import test_notebook_td_3
test_notebook_td_3.tester_exo( '2_1', globals() )

# %% [markdown]
# ### Exercice n ° 2: fonction incrémente
#
# Écrire une fonction <code>incremente</code> qui prend un argument et renvoie la valeur de cet argument + 1

# %%
## Exercise 2-2


## Don't modify following lines
import test_notebook_td_3
test_notebook_td_3.tester_exo( '2_2', globals() )

# %% [markdown]
# **Exemple 1:** Lors de l'exécution de cette cellule, il devrait afficher 1

# %%
print(incremente(0))

# %% [markdown]
# ### Exercice n ° 4: évaluer un polynôme
#
# Écrivez une fonction <code>evaluation_polynome</code> qui prend 4 arguments <code>a, b, c, x</code> et renvoie l'évaluation de polynome correspondant :
#
# $ a * x ^ 2 + b * x + c $

# %%
## Exercise 2-4


## Don't modify following lines
import test_notebook_td_3
test_notebook_td_3.tester_exo( '2_4', globals() )

# %% [markdown]
# ### Exercice N ° 5: La fonction est_pair
#
# Écrivez une fonction <code>est_pair</code> qui prend un argument et renvoie la valeur booléenne <code>True</code> si l'argument est pair, <code>False</code> sinon.
#
# Vous pouvez utiliser l'opérateur modulo pour obtenir le reste d'une division
#
# ~~~
# reste = n % x
# ~~~
#
# Essayez de le faire sans utiliser <code>if</code>

# %%
## Exercise 2-5


## Don't modify following lines
import test_notebook_td_3
test_notebook_td_3.tester_exo( '2_5', globals() )

# %% [markdown]
# ### Exercice n ° 6: fonction factorielle
#
# Écrivez une fonction <code>factorielle</code> qui prend un argument et renvoie le factoriel correspondant.
# Par exemple :
#
# ~~~
# factorielle (6) ## return 1 * 2 * 3 * 4 * 5 * 6
# factorielle (999) ## return 1 * 2 * 3 * 4 * 5 * ... * 997 * 998 * 999
# factorielle (0) ## return 1
# ~~~

# %%
## Exercise 2-6


## Don't modify following lines
import test_notebook_td_3
test_notebook_td_3.tester_exo( '2_6', globals() )

# %% [markdown]
# ### Exercice N ° 7: Fonction combinatoire

# %% [markdown]
# En utilisant la fonction factorielle de l'exercice précédent, écrivez une fonction <code>combinatoire</code> qui prend deux arguments <code>n</code> et <code>k</code> et calculez le combinatoire n, k (n étant le premier argument):
#
# $ \dbinom{n}{k} $
#
# Pour rappel, la formule combinatoire est:
#
# $ \dbinom{n}{k} = \frac{n!}{(n-k)! k!} $

# %%
## Exercise 2-7


## Don't modify following lines
import test_notebook_td_3
test_notebook_td_3.tester_exo( '2_7', globals() )

# %% [markdown]
# ## Partie 3: listes

# %%
import binascii

test_notebook_td_5_content = b'...'

with open( 'test_notebook_tp_5_liste.py', 'wb' ) as f:
    f.write( binascii.unhexlify(test_notebook_td_5_content)  )

# %% [markdown]
# ### 2.0 Exercice 0 - Les tests des tests fonctionnent
#
# Écrivez une fonction <code>creer_liste_vide</code> qui renvoie une liste vide

# %%
## Don't modify following lines
import test_notebook_tp_5_liste
test_notebook_tp_5_liste.tester_exo( 0, globals() )

# %% [markdown]
# ### 2.0 Exercice 0.1 - Manipulation de la liste de base
#
# Créez 4 listes :
#
# Une liste <code>a</code> qui contient 2 éléments, 1 et 2
# Une liste <code>b</code> qui contient 3 éléments, 3, 4 et 5
# Une liste <code>c</code> qui contient 2 éléments, les listes <code>a</code> et <code>b</code> précédemment définies
# Une liste <code>d</code> qui contient l'entier de 1 à 1000

# %%
## Don't modify following lines
import test_notebook_tp_5_liste
test_notebook_tp_5_liste.tester_exo( '0_1', globals() )

# %% [markdown]
# ### 2.0 Exercice 0.2 - Fonctions de base de liste
#
# Écrivez quelques fonctions
#
# 1. <code>ajoute</code> prend deux arguments, une liste et un élément et ajouter l'élément à la liste et ne retourner rien
# 1. <code>deuxieme_element</code> Prenez une liste comme argument et renvoyez le deuxième élément
# 1. <code>dernier_element</code> Prenez une liste comme argument et retournez le dernier élément
# 1. <code>supprimer_troisieme_element</code> Prenez une liste comme argument, et supprimez le troisième argument le 3ème élément s'il existe, et ne faites rien autrement (vous pouvez utiliser la fonction del)
#
# Par exemple :
#
# ~~~
# list = [1,2]
# ajoute(list, 4) ## ne renvoie rien, mais la nouvelle valeur de la liste est [1,2,4]
# deuxieme_element([1,6,7]) ## return 6
# dernier_element([1,6,7,9]) ## return 9
# list = [1,2]
# supprimer_troisieme_element(list) ## ne faites rien
# liste = [1,2,4,5]
# supprimer_troisieme_element(list) ## ne renvoie rien, la valeur de la liste devient [1,2,5]
# ~~~

# %%
import test_notebook_tp_5_liste
test_notebook_tp_5_liste.tester_exo( '0_2', globals() )

# %% [markdown]
# ### 2.8 Exercice 8 - Même d'abord!
#
# Écrivez une fonction <code>pair_d_abord</code>, qui prend une liste d'entier en argument, et renvoie-la avec les entiers pairs d'abord, puis les autres éléments
#
# Par exemple :
#
# ~~~
# pair_d_abord ([16, 9, 5, 13, 24]) ## retour [16, 24, 9, 5, 13]
# pair_d_abord ([16, 75, 3, 9, 4, 6, 15]) ## retour [16, 4, 6, 75, 3, 9, 15]
# ~~~

# %%
## Don't modify following lines
import test_notebook_tp_5_liste
test_notebook_tp_5_liste.tester_exo( '8', globals() )

# %% [markdown]
# La cellule suivante doit revenir [16, 4, 6, 75, 3, 9, 15]

# %%
pair_d_abord( [ 16, 75, 3, 9, 4, 6, 15 ] )
